# %%
import pandas as pd
df = {
    'name':['deepak', 'dinesh', 'shubham'],
    'age':[35, 36, 28],
    'city':['noida', 'berlin', 'brampton']
}
data_frame = pd.DataFrame(df)
# print(data_frame)
# print(type(df))
# type(data_frame['name'])
# data_frame.loc[0]
# data_frame.iloc[0][0]
# data_frame.loc[0][0]
# data_frame['name']
# data_frame.at[2, 'name']
# data_frame.iat[2,2]
data_frame['salary']=[50000, 60000, 70000]
# print(data_frame)
# data_frame.drop('salary', axis=1, inplace=True)
print(data_frame)
data_frame['age']= data_frame['age']+1
print(data_frame)
# Out:
#       name  age      city  salary
# 0   deepak   35     noida   50000
# 1   dinesh   36    berlin   60000
# 2  shubham   28  brampton   70000
#       name  age      city  salary
# 0   deepak   36     noida   50000
# 1   dinesh   37    berlin   60000
# 2  shubham   29  brampton   70000

# %%
import pandas as pd
data = [
    {'name':"deepak", 'age':36, 'city':'berlin'},
    {'name':"dinesh", 'age':37, 'city':'noida'},
    {'name':"shubham", 'age':36, 'city':'brampton'}

]

data_frame = pd.DataFrame(data)
print(data_frame)
print(type(data_frame))
# Out:
#       name  age      city
# 0   deepak   36    berlin
# 1   dinesh   37     noida
# 2  shubham   36  brampton
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
data=pd.read_csv('data.csv')
print(data.head(5))
data.tail(5)
print(type(data))
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North
# <class 'pandas.core.frame.DataFrame'>

# %%
# accessing data from data frame

# %%
import pandas as pd
data = [1,2,3,4,5]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
import pandas as pd
data = [1,2,3]
indexes = ['a','b', 'c']
final_data = pd.Series(data, index= indexes)
print(final_data)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
